# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Datasets/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Columns
#
# Numerical Columns : Age, Fare\
# Categorical Columns : Survived, Pclass, Sex, SibSp, Parch, Embarked, Cabin\
# Mixed Columns : Name, Ticket
#
# Discarded : PassengerId

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Age
#
# #### Conclusions
# - Age is normally distributed
# - 20% of the values are missing
# - There are few outliers

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Age'] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
df['Age'].isna().sum() / df['Age'].shape[0]
# Out:
# 0.19865319865319866

# %% [markdown]
# ### Fare
#
# #### Conclusions
# - Group fare is given, individual fare must be taken out
# - Data is highly skewed (positive)
# - Large amount of outliers

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893

# %%
df['Fare'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ### Survived
#
# #### Conclusions
# - 60% of people died in the accident

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Pclass
#
# #### Conclusions
# - Most passengers were of Pclass 3
# - Pclass 1 passengers were second highest in number
# - Pclass 2 passengers were the least in number

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Sex
#
# #### Conclusions
# - Majority of the passengers were male

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### SibSp
#
# #### Conclusions
# - SibSp and Parch can be combined to form 1 column

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %% [markdown]
# ### Parch
#
# #### Conclusions
# - Parch and SibSp can be combined to form 1 column

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df['Parch'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Parch'>

# %% [markdown]
# ### Embarked
#
# #### Conclusions
# -
# -

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Embarked'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Cabin
#
# #### Conclusions
# - Majority of the cabins details are missing
# - Most people were in Cabin C, B, D and E

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df['Cabin'].fillna('M', inplace = True)

# %%
df['Cabin'] = df['Cabin'].str[0]

# %%
df['Cabin']
# Out:
# 0      M
# 1      C
# 2      M
# 3      C
# 4      M
#       ..
# 886    M
# 887    B
# 888    M
# 889    C
# 890    M
# Name: Cabin, Length: 891, dtype: object

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# M    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: count, dtype: int64

# %%
df['Cabin'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cabin'>

# %% [markdown]
# ## Adding Family Size Column

# %%
df['Family_Size_Number'] = df['SibSp'] + df['Parch'] + 1
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 848          849         0       2                       Harper, Rev. John
# 199          200         0       2  Yrois, Miss. Henriette ("Mrs Harbeck")
# 180          181         0       3            Sage, Miss. Constance Gladys
# 131          132         0       3          Coelho, Mr. Domingos Fernandeo
# 273          274         0       1                   Natsch, Mr. Charles H
#
#         Sex   Age  SibSp  Parch              Ticket   Fare Cabin Embarked  \
# 848    male  28.0      0      1              248727  33.00     M        S
# 199  female  24.0      0      0              248747  13.00     M        S
# 180  female   NaN      8      2            CA. 2343  69.55     M        S
# 131    male  20.0      0      0  SOTON/O.Q. 3101307   7.05     M        S
# 273    male  37.0      0      1            PC 17596  29.70     C        C
#
#      Family_Size_Number
# 848                   2
# ...

# %%
def family_size(size):
    if size == 1:
        return 'Alone'
    elif size > 1 and size < 5:
        return 'Small'
    else:
        return 'Large'

# %%
df['Family_Size'] = df['Family_Size_Number'].apply(family_size)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Family_Size'].value_counts()
# Out:
# Family_Size
# Alone    537
# Small    292
# Large     62
# Name: count, dtype: int64

# %%
df['Family_Size'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Family_Size'>

# %%
df['Family_Size'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Survived and Pclass
#
# #### Conclusions
# - Highest probability of death -> Pclass 3
# - Lowest probability of death -> Pclass 1

# %%
pd.crosstab(df['Survived'], df['Pclass'], normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %% [markdown]
# ### Survived and Sex
# - Females had a much higher chance of survival than males

# %%
pd.crosstab(df['Survived'], df['Sex'], normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %% [markdown]
# ### Embarked
# - Passengers who embarked from Cherbourg had the highest chance of survival
# - Most paassengers who embarked on Cherbourg were from Pclass 3

# %%
pd.crosstab(df['Survived'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df['Embarked'], df['SD'], normalize='columns').plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
pd.crosstab(df['Pclass'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
pd.crosstab(df['Pclass'], df['Embarked'], normalize='index').plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# ### Survived and Deck
# - Decks B, D, E had higher chances of survival compared to other decks

# %%
pd.crosstab(df['Survived'], df['Cabin'], normalize='columns')*100
# Out:
# Cabin             A          B          C          D     E          F     G  \
# Survived
# 0         53.333333  25.531915  40.677966  24.242424  25.0  38.461538  50.0
# 1         46.666667  74.468085  59.322034  75.757576  75.0  61.538462  50.0
#
# Cabin             M      T
# Survived
# 0         70.014556  100.0
# 1         29.985444    0.0

# %%
pd.crosstab(df['Cabin'], df['Survived'], normalize='index').plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Cabin'>

# %% [markdown]
# ### Survived and Age
# - Ages 0-10 had the higher chances of survival
# - Ages 20-40 had lower chances of survival

# %%
df[df['Survived'] == 1]['Age'].plot(kind='kde', label='Survived')
df[df['Survived'] == 0]['Age'].plot(kind='kde', label='Not Survived')

plt.legend()

# %% [markdown]
# ### Survived and Family Size
# - Travelling in a small family had the highest chances of survival
# - Travelling in a large family had the lowest chances of survival

# %%
pd.crosstab(df['Survived'], df['Family_Size'], normalize='columns')*100
# Out:
# Family_Size      Alone      Large      Small
# Survived
# 0            69.646182  83.870968  42.123288
# 1            30.353818  16.129032  57.876712

# %%
df[df['Survived'] == 1]['Family_Size_Number'].plot(kind='kde', label='Survived')
df[df['Survived'] == 0]['Family_Size_Number'].plot(kind='kde', label='Not Survived')

plt.legend()

# %% [markdown]
# ## Correlation

# %%
df.corr(numeric_only=True)
# Out:
#                     PassengerId  Survived    Pclass       Age     SibSp  \
# PassengerId            1.000000 -0.005007 -0.035144  0.036847 -0.057527
# Survived              -0.005007  1.000000 -0.338481 -0.077221 -0.035322
# Pclass                -0.035144 -0.338481  1.000000 -0.369226  0.083081
# Age                    0.036847 -0.077221 -0.369226  1.000000 -0.308247
# SibSp                 -0.057527 -0.035322  0.083081 -0.308247  1.000000
# Parch                 -0.001652  0.081629  0.018443 -0.189119  0.414838
# Fare                   0.012658  0.257307 -0.549500  0.096067  0.159651
# Family_Size_Number    -0.040143  0.016639  0.065997 -0.301914  0.890712
#
#                        Parch      Fare  Family_Size_Number
# PassengerId        -0.001652  0.012658           -0.040143
# Survived            0.081629  0.257307            0.016639
# Pclass              0.018443 -0.549500            0.065997
# Age                -0.189119  0.096067           -0.301914
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# #### Conclusions
# - Survival chance is highly correlated (negative) to the Pclass of the passenger
# - Survival is slightly correlated (negative) to the age of the passenger
# - Survival is also slightly correlated (positive) to the family size of the passenger

# %%
sns.pairplot(df)
